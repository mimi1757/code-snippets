# %%
# Load libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

# Read TrainingWiDS2021 data and UnlabeledWiDS2021 data into pandas in two DataFrames

url_train = 'https://github.com/areeratk/Diabetes_Mellitus/blob/main/Resources/TrainingWiDS2021.csv?raw=true'
url_test = 'https://github.com/areeratk/Diabetes_Mellitus/blob/main/Resources/UnlabeledWiDS2021.csv?raw=true'
df = pd.read_csv(url_train)
test_df = pd.read_csv(url_test)

#Print the worksheet dataframe, df
print(df.shape)

#Print the predicting dataframe, test_df
print(test_df.shape)

# Encode string variables as new columns
df.loc[:, 'ethnicity_encode'] = pd.factorize(df['ethnicity'])[0].reshape(-1,1)
df.loc[:, 'gender_encode'] = pd.factorize(df['gender'])[0].reshape(-1,1)
df.loc[:, 'hospital_admit_source_encode'] = pd.factorize(df['hospital_admit_source'])[0].reshape(-1,1)
df.loc[:, 'icu_admit_source_encode'] = pd.factorize(df['icu_admit_source'])[0].reshape(-1,1)
df.loc[:, 'icu_stay_type_encode'] = pd.factorize(df['icu_stay_type'])[0].reshape(-1,1)
df.loc[:, 'icu_type_encode'] = pd.factorize(df['icu_type'])[0].reshape(-1,1)

# Create new variables to solve missing data and high correlation among predictors issues
df['d1_diasbp_invasive_diff'] = df['d1_diasbp_invasive_max'] - df['d1_diasbp_invasive_min']
df['d1_diasbp_diff'] = df['d1_diasbp_max'] - df['d1_diasbp_min']
df['d1_heartrate_diff'] = df['d1_heartrate_max'] - df['d1_heartrate_min']
df['d1_mbp_diff'] = df['d1_mbp_max'] - df['d1_mbp_min']
df['d1_spo2_diff'] = df['d1_spo2_max'] - df['d1_spo2_min']
df['d1_sysbp_diff'] = df['d1_sysbp_max'] - df['d1_sysbp_min']
df['d1_calcium_diff'] = df['d1_calcium_max'] - df['d1_calcium_min']
df['d1_inr_diff'] = df['d1_inr_max'] - df['d1_inr_min']
df['d1_temp_diff'] = df['d1_temp_max'] - df['d1_temp_min']
df['h1_diasbp_diff'] = df['h1_diasbp_max'] - df['h1_diasbp_min']
df['h1_heartrate_diff'] = df['h1_heartrate_max'] - df['h1_heartrate_min']
df['h1_mbp_diff'] = df['h1_mbp_max'] - df['h1_mbp_min']
df['h1_resprate_diff'] = df['h1_resprate_max'] - df['h1_resprate_min']
df['h1_spo2_diff'] = df['h1_spo2_max'] - df['h1_spo2_min']
df['h1_sysbp_diff'] = df['h1_sysbp_max'] - df['h1_sysbp_min']
df['gcs_sum']=df['gcs_eyes_apache']+df['gcs_motor_apache']+df['gcs_verbal_apache']
df['bmi_calculated'] = 10000 * df['weight']/(df['height']**2)

# Drop columns of the original variables after columns of further relevant and related variables are created
df = df.drop(['d1_diasbp_invasive_max', 'd1_diasbp_invasive_min', 'd1_diasbp_max', 'd1_diasbp_min', 'd1_heartrate_max', 'd1_heartrate_min', 'd1_mbp_max', 'd1_mbp_min', 'd1_spo2_max', 'd1_spo2_min',
              'd1_sysbp_max', 'd1_sysbp_min', 'd1_calcium_max', 'd1_calcium_min', 'd1_inr_max', 'd1_inr_min', 'd1_temp_max', 'd1_temp_min', 'h1_diasbp_max', 'h1_diasbp_min',
              'h1_heartrate_max', 'h1_heartrate_min', 'h1_mbp_max', 'h1_mbp_min', 'h1_resprate_max', 'h1_resprate_min', 'h1_spo2_max', 'h1_spo2_min', 'h1_sysbp_max', 'h1_sysbp_min', 
              'gcs_eyes_apache', 'gcs_motor_apache', 'gcs_verbal_apache', 'ethnicity', 'gender', 'hospital_admit_source', 'icu_admit_source', 'icu_stay_type', 'icu_type', 'bmi'
              ], axis=1)

# Impute remaining missing value with zeroes
df = df.fillna(0)

#Prepare the predicting dataframe, testing_df, following the same procedure describe in the immidiate cell above

# Encode string variables as new columns
test_df.loc[:, 'ethnicity_encode'] = pd.factorize(test_df['ethnicity'])[0].reshape(-1,1)
test_df.loc[:, 'gender_encode'] = pd.factorize(test_df['gender'])[0].reshape(-1,1)
test_df.loc[:, 'hospital_admit_source_encode'] = pd.factorize(test_df['hospital_admit_source'])[0].reshape(-1,1)
test_df.loc[:, 'icu_admit_source_encode'] = pd.factorize(test_df['icu_admit_source'])[0].reshape(-1,1)
test_df.loc[:, 'icu_stay_type_encode'] = pd.factorize(test_df['icu_stay_type'])[0].reshape(-1,1)
test_df.loc[:, 'icu_type_encode'] = pd.factorize(test_df['icu_type'])[0].reshape(-1,1)

# Create new variables to solve missing data and high correlation among predictors issues
test_df['d1_diasbp_invasive_diff'] = test_df['d1_diasbp_invasive_max'] - test_df['d1_diasbp_invasive_min']
test_df['d1_diasbp_diff'] = test_df['d1_diasbp_max'] - test_df['d1_diasbp_min']
test_df['d1_heartrate_diff'] = test_df['d1_heartrate_max'] - test_df['d1_heartrate_min']
test_df['d1_mbp_diff'] = test_df['d1_mbp_max'] - test_df['d1_mbp_min']
test_df['d1_spo2_diff'] = test_df['d1_spo2_max'] - test_df['d1_spo2_min']
test_df['d1_sysbp_diff'] = test_df['d1_sysbp_max'] - test_df['d1_sysbp_min']
test_df['d1_calcium_diff'] = test_df['d1_calcium_max'] - test_df['d1_calcium_min']
test_df['d1_inr_diff'] = test_df['d1_inr_max'] - test_df['d1_inr_min']
test_df['d1_temp_diff'] = test_df['d1_temp_max'] - test_df['d1_temp_min']
test_df['h1_diasbp_diff'] = test_df['h1_diasbp_max'] - test_df['h1_diasbp_min']
test_df['h1_heartrate_diff'] = test_df['h1_heartrate_max'] - test_df['h1_heartrate_min']
test_df['h1_mbp_diff'] = test_df['h1_mbp_max'] - test_df['h1_mbp_min']
test_df['h1_resprate_diff'] = test_df['h1_resprate_max'] - test_df['h1_resprate_min']
test_df['h1_spo2_diff'] = test_df['h1_spo2_max'] - test_df['h1_spo2_min']
test_df['h1_sysbp_diff'] = test_df['h1_sysbp_max'] - test_df['h1_sysbp_min']
test_df['gcs_sum']=test_df['gcs_eyes_apache']+test_df['gcs_motor_apache']+test_df['gcs_verbal_apache']
test_df['bmi_calculated'] = 10000 * test_df['weight']/(test_df['height']**2)

# Drop columns of the original variables after columns of further relevant and related variables are created
test_df = test_df.drop(['d1_diasbp_invasive_max', 'd1_diasbp_invasive_min', 'd1_diasbp_max', 'd1_diasbp_min', 'd1_heartrate_max', 'd1_heartrate_min', 'd1_mbp_max', 'd1_mbp_min', 'd1_spo2_max', 'd1_spo2_min',
              'd1_sysbp_max', 'd1_sysbp_min', 'd1_calcium_max', 'd1_calcium_min', 'd1_inr_max', 'd1_inr_min', 'd1_temp_max', 'd1_temp_min', 'h1_diasbp_max', 'h1_diasbp_min',
              'h1_heartrate_max', 'h1_heartrate_min', 'h1_mbp_max', 'h1_mbp_min', 'h1_resprate_max', 'h1_resprate_min', 'h1_spo2_max', 'h1_spo2_min', 'h1_sysbp_max', 'h1_sysbp_min', 
              'gcs_eyes_apache', 'gcs_motor_apache', 'gcs_verbal_apache', 'ethnicity', 'gender', 'hospital_admit_source', 'icu_admit_source', 'icu_stay_type', 'icu_type', 'bmi'
              ], axis=1)

# Impute remaining missing value with zeroes
test_df = test_df.fillna(0)

#Read cleaned test_df dataframe ready for prediction from a selected machine learning model
test_df
# Out:
# (130157, 181)
# (10234, 180)
#        Unnamed: 0  encounter_id  ...  gcs_sum  bmi_calculated
# 0               1        144740  ...     15.0        0.000000
# 1               2        141990  ...     15.0        0.000000
# 2               3        142038  ...     15.0        0.000000
# 3               4        138628  ...     14.0        0.000000
# 4               5        141682  ...     15.0        0.000000
# ...           ...           ...  ...      ...             ...
# 10229       10230        143750  ...     14.0       37.533684
# 10230       10231        143813  ...     15.0       32.148438
# 10231       10232        137126  ...     15.0       22.745608
# 10232       10233        135652  ...     14.0       19.882812
# 10233       10234        136852  ...      8.0       25.622500
#
# [10234 rows x 163 columns]

# %%
#split dataset in features and target variable in the worksheet dataframe, df
feature_cols = [
 'age',
 'bmi_calculated',
 'apache_2_diagnosis',
 'apache_3j_diagnosis',
 'gcs_sum',
 'heart_rate_apache',
 'map_apache',
 'resprate_apache',
 'temp_apache',
 'd1_diasbp_diff',
 'd1_heartrate_diff',
 'd1_mbp_diff',
 'd1_resprate_max',
 'd1_spo2_diff',
 'd1_sysbp_diff',
 'd1_temp_diff',
 'd1_bun_max',
 'd1_calcium_diff',
 'd1_glucose_max',
 'd1_hco3_max',
 'd1_platelets_max',
 'd1_potassium_min',
 'd1_sodium_min',
 'h1_glucose_max',
 ]
X = df[feature_cols] # Features
y = df.diabetes_mellitus # Target variable

#Keep only relevant features in the predicting dataframe, testing_df, similar to the features in the worksheet dataframe immediately above
test_feature_cols = [
 'age',
 'bmi_calculated',
 'apache_2_diagnosis',
 'apache_3j_diagnosis',
 'gcs_sum',
 'heart_rate_apache',
 'map_apache',
 'resprate_apache',
 'temp_apache',
 'd1_diasbp_diff',
 'd1_heartrate_diff',
 'd1_mbp_diff',
 'd1_resprate_max',
 'd1_spo2_diff',
 'd1_sysbp_diff',
 'd1_temp_diff',
 'd1_bun_max',
 'd1_calcium_diff',
 'd1_glucose_max',
 'd1_hco3_max',
 'd1_platelets_max',
 'd1_potassium_min',
 'd1_sodium_min',
 'h1_glucose_max',
 ]
Xt = test_df[feature_cols] # Features for the test-df dataframe

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

X_train.shape
# Out:
# (91109, 24)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
from numpy import mean
from numpy import std
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score


bestmodel = GradientBoostingClassifier(n_estimators=100, subsample = 0.6, max_features=11, learning_rate = 0.1, max_depth = 7)
bestmodel.fit(X_train,y_train)
predictions = bestmodel.predict(X_test)

print(accuracy_score(y_test, predictions))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))

predictions_sub = bestmodel.predict(Xt)
# Out:
# 0.8209383323089531
# [[28474  2142]
#  [ 4850  3582]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89     30616
#            1       0.63      0.42      0.51      8432
#
#     accuracy                           0.82     39048
#    macro avg       0.74      0.68      0.70     39048
# weighted avg       0.81      0.82      0.81     39048

# %%
from numpy import arange
def get_models():
  models = dict()
  for i in [0.0001, 0.001, 0.01, 0.1, 1.0]:
    for j in range(1,21):
      for k in arange(0.1, 1.1, 0.1):
        key = "learning_rate = {:.4f} max_features = {:,.4f} subsample= {:,.1f}".format(i,j,k) 
        models[key] = GradientBoostingClassifier(learning_rate=i, max_features=j, subsample=k)
  return models
 
def evaluate_model(model, X, y):
	
	scores = model.score(X, y)
	return scores
 

models = get_models()
results, names = list(), list()
for name, model in models.items():
  model.fit(X_train, y_train)
  scores = model.score(X_test, y_test)
  results.append(scores)
  names.append(name)
  print('>%s %.3f ' % (name, mean(scores)))
# Out:
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 1.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 2.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 3.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 4.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 5.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 6.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 7.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 8.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 9.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 10.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 11.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 12.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 13.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 14.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 15.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 16.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 17.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 18.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 19.0000 subsample= 1.0 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.1 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.2 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.3 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.4 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.5 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.6 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.7 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.8 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 0.9 0.784
# >learning_rate = 0.0001 max_features = 20.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 1.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 2.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 3.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 4.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 5.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 6.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 7.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 8.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 9.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 10.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 11.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 12.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 13.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 14.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 15.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 16.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 17.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 18.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 19.0000 subsample= 1.0 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.1 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.2 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.3 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.4 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.5 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.6 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.7 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.8 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 0.9 0.784
# >learning_rate = 0.0010 max_features = 20.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 1.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 2.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 3.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 4.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 5.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 6.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 7.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.1 0.785
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 8.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.1 0.785
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 9.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.1 0.785
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 10.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.1 0.786
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 11.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.1 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 12.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.1 0.785
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 13.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.1 0.786
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 14.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.1 0.787
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 15.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.1 0.785
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 16.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.1 0.786
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 17.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.1 0.787
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 18.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.1 0.786
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 19.0000 subsample= 1.0 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.1 0.785
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.2 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.3 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.4 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.5 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.6 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.7 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.8 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 0.9 0.784
# >learning_rate = 0.0100 max_features = 20.0000 subsample= 1.0 0.784
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.1 0.807
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.2 0.801
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.3 0.801
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.4 0.805
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.5 0.805
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.6 0.806
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.7 0.804
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.8 0.803
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 0.9 0.807
# >learning_rate = 0.1000 max_features = 1.0000 subsample= 1.0 0.807
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.1 0.814
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.2 0.813
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.3 0.814
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.4 0.815
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.5 0.816
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.6 0.814
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.7 0.815
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.8 0.812
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 0.9 0.815
# >learning_rate = 0.1000 max_features = 2.0000 subsample= 1.0 0.813
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.1 0.816
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.2 0.818
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.3 0.816
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.4 0.817
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.5 0.816
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.6 0.817
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.7 0.817
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.8 0.816
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 0.9 0.817
# >learning_rate = 0.1000 max_features = 3.0000 subsample= 1.0 0.819
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.1 0.816
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.2 0.816
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.3 0.819
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.4 0.817
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.5 0.819
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.6 0.818
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.7 0.817
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.8 0.819
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 0.9 0.819
# >learning_rate = 0.1000 max_features = 4.0000 subsample= 1.0 0.818
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.1 0.819
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.2 0.817
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.3 0.819
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.4 0.820
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.5 0.819
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.6 0.820
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.7 0.820
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.8 0.819
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 0.9 0.820
# >learning_rate = 0.1000 max_features = 5.0000 subsample= 1.0 0.819
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.1 0.816
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.2 0.819
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.3 0.819
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.4 0.820
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.5 0.820
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.6 0.820
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.7 0.819
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.8 0.819
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 0.9 0.819
# >learning_rate = 0.1000 max_features = 6.0000 subsample= 1.0 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.1 0.817
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.2 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.3 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.4 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.5 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.6 0.819
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.7 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.8 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 0.9 0.820
# >learning_rate = 0.1000 max_features = 7.0000 subsample= 1.0 0.819
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.1 0.820
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.2 0.819
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.3 0.821
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.4 0.821
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.5 0.820
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.6 0.820
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.7 0.820
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.8 0.819
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 0.9 0.820
# >learning_rate = 0.1000 max_features = 8.0000 subsample= 1.0 0.820
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.1 0.819
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.2 0.819
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.3 0.820
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.4 0.819
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.5 0.819
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.6 0.821
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.7 0.820
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.8 0.819
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 0.9 0.820
# >learning_rate = 0.1000 max_features = 9.0000 subsample= 1.0 0.819
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.1 0.818
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.2 0.819
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.3 0.819
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.4 0.820
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.5 0.821
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.6 0.821
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.7 0.820
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.8 0.820
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 0.9 0.821
# >learning_rate = 0.1000 max_features = 10.0000 subsample= 1.0 0.821
# ...
# >learning_rate = 0.1000 max_features = 17.0000 subsample= 0.8 0.821
# >learning_rate = 0.1000 max_features = 17.0000 subsample= 0.9 0.820
# >learning_rate = 0.1000 max_features = 17.0000 subsample= 1.0 0.821
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.1 0.819
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.2 0.820
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.3 0.820
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.4 0.820
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.5 0.821
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.6 0.822
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.7 0.821
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.8 0.821
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 0.9 0.821
# >learning_rate = 0.1000 max_features = 18.0000 subsample= 1.0 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.1 0.818
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.2 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.3 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.4 0.820
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.5 0.822
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.6 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.7 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.8 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 0.9 0.821
# >learning_rate = 0.1000 max_features = 19.0000 subsample= 1.0 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.1 0.819
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.2 0.820
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.3 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.4 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.5 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.6 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.7 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.8 0.821
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 0.9 0.822
# >learning_rate = 0.1000 max_features = 20.0000 subsample= 1.0 0.822
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.1 0.783
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.2 0.797
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.3 0.802
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.4 0.803
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.5 0.808
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.6 0.807
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.7 0.809
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.8 0.809
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 0.9 0.811
# >learning_rate = 1.0000 max_features = 1.0000 subsample= 1.0 0.809
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.1 0.780
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.2 0.793
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.3 0.802
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.5 0.807
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.6 0.808
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.7 0.811
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.8 0.808
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 0.9 0.812
# >learning_rate = 1.0000 max_features = 2.0000 subsample= 1.0 0.812
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.1 0.777
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.2 0.796
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.3 0.801
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.5 0.807
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.6 0.811
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.7 0.812
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.8 0.812
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 0.9 0.810
# >learning_rate = 1.0000 max_features = 3.0000 subsample= 1.0 0.813
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.1 0.781
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.2 0.791
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.3 0.803
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.4 0.809
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.5 0.808
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.6 0.811
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.7 0.808
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.8 0.810
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 0.9 0.816
# >learning_rate = 1.0000 max_features = 4.0000 subsample= 1.0 0.815
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.1 0.783
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.2 0.798
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.3 0.799
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.4 0.803
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.5 0.810
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.6 0.810
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.7 0.814
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 0.9 0.815
# >learning_rate = 1.0000 max_features = 5.0000 subsample= 1.0 0.813
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.1 0.787
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.2 0.796
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.3 0.803
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.5 0.808
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.6 0.810
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.7 0.811
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.8 0.813
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 0.9 0.812
# >learning_rate = 1.0000 max_features = 6.0000 subsample= 1.0 0.812
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.1 0.788
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.2 0.792
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.3 0.805
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.4 0.806
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.5 0.806
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.6 0.810
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.7 0.810
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.8 0.812
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 0.9 0.816
# >learning_rate = 1.0000 max_features = 7.0000 subsample= 1.0 0.816
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.1 0.788
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.2 0.799
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.3 0.804
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.4 0.805
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.5 0.806
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.6 0.809
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.7 0.813
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.8 0.813
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 0.9 0.816
# >learning_rate = 1.0000 max_features = 8.0000 subsample= 1.0 0.815
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.1 0.781
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.2 0.799
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.3 0.802
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.5 0.810
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.6 0.812
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.7 0.812
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.8 0.812
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 0.9 0.816
# >learning_rate = 1.0000 max_features = 9.0000 subsample= 1.0 0.812
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.1 0.795
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.2 0.800
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.3 0.805
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.4 0.809
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.5 0.811
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.6 0.809
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.7 0.810
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 0.9 0.813
# >learning_rate = 1.0000 max_features = 10.0000 subsample= 1.0 0.814
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.1 0.789
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.2 0.801
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.3 0.803
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.4 0.806
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.5 0.809
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.6 0.813
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.7 0.809
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.8 0.815
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 0.9 0.814
# >learning_rate = 1.0000 max_features = 11.0000 subsample= 1.0 0.816
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.1 0.785
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.2 0.799
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.3 0.804
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.4 0.804
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.5 0.806
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.6 0.814
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.7 0.811
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 0.9 0.813
# >learning_rate = 1.0000 max_features = 12.0000 subsample= 1.0 0.815
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.1 0.780
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.2 0.796
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.3 0.804
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.4 0.806
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.5 0.810
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.6 0.810
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.7 0.812
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.8 0.815
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 0.9 0.813
# >learning_rate = 1.0000 max_features = 13.0000 subsample= 1.0 0.815
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.1 0.786
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.2 0.802
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.3 0.804
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.4 0.810
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.5 0.810
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.6 0.812
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.7 0.813
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.8 0.813
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 0.9 0.811
# >learning_rate = 1.0000 max_features = 14.0000 subsample= 1.0 0.816
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.1 0.787
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.2 0.799
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.3 0.804
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.5 0.810
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.6 0.811
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.7 0.812
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 0.9 0.814
# >learning_rate = 1.0000 max_features = 15.0000 subsample= 1.0 0.817
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.1 0.791
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.2 0.799
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.3 0.805
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.4 0.806
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.5 0.810
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.6 0.811
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.7 0.813
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 0.9 0.815
# >learning_rate = 1.0000 max_features = 16.0000 subsample= 1.0 0.814
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.1 0.790
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.2 0.796
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.3 0.801
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.5 0.806
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.6 0.811
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.7 0.812
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 0.9 0.816
# >learning_rate = 1.0000 max_features = 17.0000 subsample= 1.0 0.815
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.1 0.786
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.2 0.795
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.3 0.805
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.4 0.805
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.5 0.808
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.6 0.812
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.7 0.813
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.8 0.814
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 0.9 0.814
# >learning_rate = 1.0000 max_features = 18.0000 subsample= 1.0 0.815
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.1 0.785
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.2 0.798
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.3 0.800
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.4 0.806
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.5 0.809
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.6 0.810
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.7 0.812
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.8 0.813
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 0.9 0.814
# >learning_rate = 1.0000 max_features = 19.0000 subsample= 1.0 0.817
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.1 0.789
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.2 0.800
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.3 0.803
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.4 0.807
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.5 0.811
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.6 0.810
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.7 0.813
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.8 0.812
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 0.9 0.815
# >learning_rate = 1.0000 max_features = 20.0000 subsample= 1.0 0.815
